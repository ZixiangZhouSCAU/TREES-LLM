# %% [markdown]
# # 04 - 结果分析
#
# 评估模型性能，可视化结果

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
from pathlib import Path

from src.scripts.eval_metrics import evaluate_tree_params
from src.utils.visualization import plot_tree_parameters

# %%
# TODO: 加载预测结果和真值
# predictions = load_predictions('./outputs/predictions.json')
# ground_truth = load_ground_truth('./data/03_ground_truth/')

# results = evaluate_tree_params(predictions, ground_truth)
# print(results)
